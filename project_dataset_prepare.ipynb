# %%
import os
import zipfile
import re
import csv

# Function to append data to a file
def append_to_file(data, filename):
    # Check if file exists to write headers
    file_exists = False
    try:
        with open(filename, 'r') as f:
            file_exists = True
    except FileNotFoundError:
        pass

    with open(filename, 'a', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=data.keys())
        if not file_exists:
            writer.writeheader()
        writer.writerow(data)

def extract_vrt_data_from_chunk(chunk):
    # Extract attributes of <text> element
    msg_type = re.search(r'msg_type="(.*?)"', chunk).group(1)
    datetime = re.search(r'datetime="(.*?)"', chunk).group(1)
    title = re.search(r'title="(.*?)"', chunk).group(1)
    thread_id = re.search(r'thread_id="(.*?)"', chunk).group(1)
    comment_id = re.search(r'comment_id="(.*?)"', chunk).group(1)
    topic_name_top = re.search(r'topic_name_top="(.*?)"', chunk).group(1)
    topic_name_leaf = re.search(r'topic_name_leaf="(.*?)"', chunk).group(1)

    # Extract sentences
    sentences = re.findall(r'<sentence(.*?)</sentence>', chunk, re.DOTALL)
    thread_text = ' '.join([' '.join(re.findall(r'^(\S+?)\t', sentence, re.MULTILINE)) for sentence in sentences])

    return {
        'msg_type': msg_type,
        'datetime': datetime,
        'title': title,
        'thread_id':thread_id,
        'comment_id':comment_id,
        'topic_name_top':topic_name_top,
        'topic_name_leaf':topic_name_leaf,
        'thread_text': thread_text,
    }

def process_file_in_chunks(file_path, num_messages):
    chunk = ""
    count = 0

    with open(file_path, 'r', encoding='utf-8', errors='replace') as file:
        for line in file:
            chunk += line
            if '</text>' in line:
                yield extract_vrt_data_from_chunk(chunk)
                chunk = ""
                count += 1
                if count%num_messages == 0:
                    print(f"{count} number of messages Done!")
                # if count >= num_messages:
                #     break

def process_zip_files(zip_filenames, output_file):
    for zip_filename in zip_filenames:
        # Open the zip file
        with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
            # Iterate over each .vrt file in the zip archive
            for vrt_file in zip_ref.namelist():
                if vrt_file.endswith('.vrt'):
                    with zip_ref.open(vrt_file, 'r') as file:
                        chunk = ""
                        count = 0
                        for line in file:
                            line = line.decode('utf-8', errors='replace')
                            chunk += line
                            if '</text>' in line:
                                entry = extract_vrt_data_from_chunk(chunk)
                                append_to_file(entry, output_file)
                                chunk = ""
                                count += 1
                                if count % num_messages == 0:
                                    print(f"{count} number of messages Done from {zip_filename}/{vrt_file}!")


zip_files = ['data/suomi24-2001-2017-vrt-v1-2.zip', 'data/suomi24-2018-2020-vrt-beta.zip']
output_file = 'data/parsed_data.csv'
num_messages = 500  # Change this to the number of messages you want to parse per file

process_zip_files(zip_files, output_file)

print("Done!")
# Out:
# 500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 1000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 1500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 2000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 2500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 3000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 3500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 4000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 4500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 5000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 5500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 6000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 6500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 7000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 7500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 8000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 8500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 9000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 9500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 10000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 10500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 11000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 11500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 12000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 12500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 13000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 13500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 14000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 14500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 15000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 15500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 16000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 16500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 17000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 17500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 18000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 18500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 19000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 19500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 20000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 20500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 21000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 21500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 22000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 22500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 23000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 23500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 24000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 24500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 25000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 25500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 26000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 26500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 27000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 27500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 28000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 28500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 29000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 29500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 30000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 30500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 31000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 31500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 32000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 32500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 33000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 33500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 34000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 34500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 35000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 35500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 36000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 36500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 37000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 37500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 38000 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# 38500 number of messages Done from data/suomi24-2001-2017-vrt-v1-2.zip/suomi24-2001-2017-vrt-v1-2/vrt/s24_2001.vrt!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\aghaffar23\OneDrive - Oulun yliopisto\Work\Uni\Courses\NLP\codes\Project\suomi24_analysis\project_dataset_prepare.ipynb Cell 1 line 8
#      <a href='vscode-notebook-cell:/c%3A/Users/aghaffar23/OneDrive%20-%20Oulun%20yliopisto/Work/Uni/Courses/NLP/codes/Project/suomi24_analysis/project_dataset_prepare.ipynb#W1sZmlsZQ%3D%3D?line=85'>86</a> output_file = 'data/parsed_data.csv'
#      <a href='vscode-notebook-cell:/c%3A/Users/aghaffar23/OneDrive%20-%20Oulun%20yliopisto/Work/Uni/Courses/NLP/codes/Project/suomi24_analysis/project_dataset_prepare.ipynb#W1sZmlsZQ%3D%3D?line=86'>87</a> num_messages = 500  # Change this to the number of messages you want to parse per file
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aghaffar23/OneDrive%20-%20Oulun%20yliopisto/Work/Uni/Courses/NLP/codes/Project/suomi24_analysis/project_dataset_prepare.ipynb#W1sZmlsZQ%3D%3D?line=88'>89</a> process_zip_files(zip_files, output_file)
#      <a href='vscode-notebook-cell:/c%3A/Users/aghaffar23/OneDrive%20-%20Oulun%20yliopisto/Work/Uni/Courses/NLP/codes/Project/suomi24_analysis/project_dataset_prepare.ipynb#W1sZmlsZQ%3D%3D?line=90'>91</a> print("Done!")
#
# c:\Users\aghaffar23\OneDrive - Oulun yliopisto\Work\Uni\Courses\NLP\codes\Project\suomi24_analysis\project_dataset_prepare.ipynb Cell 1 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/aghaffar23/OneDrive%20-%20Oulun%20yliopisto/Work/Uni/Courses/NLP/codes/Project/suomi24_analysis/project_dataset_prepare.ipynb#W1sZmlsZQ%3D%3D?line=75'>76</a> if '</text>' in line:
#      <a href='vscode-notebook-cell:/c%3A/Users/aghaffar23/OneDrive%20-%20Oulun%20yliopisto/Work/Uni/Courses/NLP/codes/Project/suomi24_analysis/project_dataset_prepare.ipynb#W1sZmlsZQ%3D%3D?line=76'>77</a>     entry = extract_vrt_data_from_chunk(chunk)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aghaffar23/OneDrive%20-%20Oulun%20yliopisto/Work/Uni/Courses/NLP/codes/Project/suomi24_analysis/project_dataset_prepare.ipynb#W1sZmlsZQ%3D%3D?line=77'>78</a>     append_to_file(entry, output_file)
#      <a href='vscode-notebook-cell:/c%3A/Users/aghaffar23/OneDrive%20-%20Oulun%20yliopisto/Work/Uni/Courses/NLP/codes/Project/suomi24_analysis/project_dataset_prepare.ipynb#W1sZmlsZQ%3D%3D?line=78'>79</a>     chunk = ""
#      <a href='vscode-notebook-cell:/c%3A/Users/aghaffar23/OneDrive%20-%20Oulun%20yliopisto/Work/Uni/Courses/NLP/codes/Project/suomi24_analysis/project_dataset_prepare.ipynb#W1sZmlsZQ%3D%3D?line=79'>80</a>     count += 1
#
# c:\Users\aghaffar23\OneDrive - Oulun yliopisto\Work\Uni\Courses\NLP\codes\Project\suomi24_analysis\project_dataset_prepare.ipynb Cell 1 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/aghaffar23/OneDrive%20-%20Oulun%20yliopisto/Work/Uni/Courses/NLP/codes/Project/suomi24_analysis/project_dataset_prepare.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> file_exists = False
#      <a href='vscode-notebook-cell:/c%3A/Users/aghaffar23/OneDrive%20-%20Oulun%20yliopisto/Work/Uni/Courses/NLP/codes/Project/suomi24_analysis/project_dataset_prepare.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> try:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aghaffar23/OneDrive%20-%20Oulun%20yliopisto/Work/Uni/Courses/NLP/codes/Project/suomi24_analysis/project_dataset_prepare.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a>     with open(filename, 'r') as f:
#      <a href='vscode-notebook-cell:/c%3A/Users/aghaffar23/OneDrive%20-%20Oulun%20yliopisto/Work/Uni/Courses/NLP/codes/Project/suomi24_analysis/project_dataset_prepare.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a>         file_exists = True
#      <a href='vscode-notebook-cell:/c%3A/Users/aghaffar23/OneDrive%20-%20Oulun%20yliopisto/Work/Uni/Courses/NLP/codes/Project/suomi24_analysis/project_dataset_prepare.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> except FileNotFoundError:
#
# File c:\Users\aghaffar23\OneDrive - Oulun yliopisto\Work\Uni\Courses\NLP\codes\venv\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# File <frozen codecs>:260, in __init__(self, errors)
#
# KeyboardInterrupt:
